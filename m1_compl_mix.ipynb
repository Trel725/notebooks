# %%
import numpy as np
from plotly import express as px
import plotly.graph_objects as go

x = np.linspace(100, 4278, 2090)

# %%
store -r mix_vs_compl_vs_m1

# %%
fig = go.Figure(layout={"height": 800, "width": 1000})
for key in mix_vs_compl_vs_m1:
    fig.add_trace(go.Scatter(x=x, y=mix_vs_compl_vs_m1[key]))
fig.show()
# Out:
# <div>
#
#
#             <div id="ae61fb6c-6de8-411f-a7d6-40b2e8e4092f" class="plotly-graph-div" style="height:800px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ae61fb6c-6de8-411f-a7d6-40b2e8e4092f")) {
#                     Plotly.newPlot(
#                         'ae61fb6c-6de8-411f-a7d6-40b2e8e4092f',
# ...
